# %%
# !pip install python-box==6.0.2 ensure==1.0.2
# Out:
# Requirement already satisfied: python-box==6.0.2 in c:\users\user\anaconda3\envs\cancer\lib\site-packages (6.0.2)
# Requirement already satisfied: ensure==1.0.2 in c:\users\user\anaconda3\envs\cancer\lib\site-packages (1.0.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\user\anaconda3\envs\cancer\lib\site-packages (from ensure==1.0.2) (1.16.0)

# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %% [markdown]
# ### Download data from gdrive

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Using cached gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting beautifulsoup4 (from gdown)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests[socks] (from gdown)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from gdown)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\anaconda3\envs\cancer\lib\site-packages (from beautifulsoup4->gdown) (4.12.2)
# Collecting charset_normalizer<4,>=2 (from requests[socks]->gdown)
#   Downloading charset_normalizer-3.4.4-cp38-cp38-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests[socks]->gdown)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests[socks]->gdown)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests[socks]->gdown)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\cancer\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.1-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Downloading charset_normalizer-3.4.4-cp38-cp38-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Installing collected packages: urllib3, tqdm, soupsieve, PySocks, idna, filelock, charset_normalizer, certifi, requests, beautifulsoup4, gdown
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.14.3 certifi-2026.1.4 charset_normalizer-3.4.4 filelock-3.16.1 gdown-5.2.1 idna-3.11 requests-2.32.4 soupsieve-2.7 tqdm-4.67.1 urllib3-2.2.3

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1goQO0h5JXWvlWH5VA0tTyO3to2dDHzBf/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1goQO0h5JXWvlWH5VA0tTyO3to2dDHzBf'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1goQO0h5JXWvlWH5VA0tTyO3to2dDHzBf
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1goQO0h5JXWvlWH5VA0tTyO3to2dDHzBf&confirm=t&uuid=cced67aa-74af-4ac8-b1e4-5f926db88538
# To: d:\Research\DL and Computer Vision Project\End-to-End-Chest-Cancer-Classification-using-MLflow-DVC\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:27<00:00, 1.77MB/s]
# 'Chest-CT-Scan-data.zip'
